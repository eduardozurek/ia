# %% [markdown]
# La heuristica01 se calcula:
# representando en decimal la primera y la ultima
# columna y sumando las representaciones

# %%
def heuristica01(t,n):
    h = 0.0
    p1 = len(t[0])-1
    for d in t[0]:
        h = h + d*10**p1
        p1 = p1 - 1
    p1 = len(t[2])-1
    for d in t[2]:
        h = h + d*10**p1
        p1 = p1 - 1
    n1 = 2.0**n-1.0
    n2 = 54321.0
    return n1*(1.0-h/n2)

# %% [markdown]
# La heuristica02 se calcula: Se suman los elementos de la ultima columna

# %%
def heuristica02(t,n):
    h = 0.0
    for d in t[2]:
        h = h + d
    return (2.0**n-1.0)*(1-h/(n*(n+1)/2))

# %% [markdown]
# La heuristica03 se calcula: Se suman los elementos de las dos ultimas columnas

# %%
def heuristica03(t,n):
    h1 = 0.0
    for d in t[1]:
        h1 = h1 + d
    h2 = 0.0
    for d in t[2]:
        h2 = h2 + d
    h = h1+2.0*h2
    return (2.0**n-1.0)*(1.0-h/(n*(n+1)))

# %%
def heuristica04(t,n):
    h1 = 0.0
    for d in t[1]:
        h1 = h1 + d
    h2 = 0.0
    for d in t[2]:
        h2 = h2 + d
    h = 2.0*h1+3.0*h2
    return (2.0**n-1.0)*(1.0-h/56.0)

# %% [markdown]
# Aquí viene la implementación de A* que usa las heurísticas anteriores

# %%
import copy
inicial=[[5,4,3,2,1],[],[]]
print ("Estado Inicial")
print (inicial)
solucion = []
solucion.append(inicial)
espacio = []
distancia = []
distancia_actual = 0.0
padre_solucion = []
padre_solucion.append(inicial)
padre_espacio = []
final=[[],[],[5,4,3,2,1]]
ind = [[0,1],[0,2],[1,0],[1,2],[2,0],[2,1]]
actual = copy.deepcopy(inicial)
s = 0
iteraciones = 0
while (s==0): 
    print ("Estado Actual")
    print (actual)
    print ("Generando hijos")
    iteraciones = iteraciones + 1
    for i1 in ind:
        nt = copy.deepcopy(actual)
        if nt[i1[0]]:
            t = nt[i1[0]].pop()
            if not nt[i1[1]]:
                nt[i1[1]].append(t)
            else:
                t1 = nt[i1[1]].pop()
                if t1 > t:
                    nt[i1[1]].append(t1)
                    nt[i1[1]].append(t)
                else:
                    nt = []
        else:
            nt = []
        for n in solucion:
            if nt == n:
                nt = []
        for n in espacio:
            if nt == n:
                nt = []
        if nt:
            print ("Hijo ", i1)
            print (nt)
            espacio.append(nt)
            distancia.append(distancia_actual+1.0)
            padre_espacio.append(actual)
    
    print ("Calculando las heuristicas")
    mejor = 0
    hdtotal = 1000000
    index = 0
    if espacio:
        for t in espacio:
            d = distancia[index]
            h = heuristica02(t,5.0)
            hd = h + d
            print( h,d,hd,t)
            if hd < hdtotal:
                hdtotal = hd
                mejor = index
            index = index + 1
        actual = espacio.pop(mejor)
        distancia_actual = distancia.pop(mejor)
        padre_solucion.append(padre_espacio.pop(mejor))
        solucion.append(actual)
    else:
        s = 5
    if actual == final:
        s = 5
ruta = []
t=solucion.pop()
ruta.append(t)
tp = padre_solucion.pop()
while (tp!=inicial):
    ruta.insert(0,tp)
    i1 = solucion.index(tp)
    t = solucion.pop(i1)
    tp = padre_solucion.pop(i1)
ruta.insert(0,inicial)
print ("Solucion")
n1 = 0
for n in ruta:
    print (n1, n)
    n1 = n1 +1
print ("Iteraciones = ")
print (iteraciones)
# Out:
# Estado Inicial
# [[5, 4, 3, 2, 1], [], []]
# Estado Actual
# [[5, 4, 3, 2, 1], [], []]
# Generando hijos
# Hijo  [0, 1]
# [[5, 4, 3, 2], [1], []]
# Hijo  [0, 2]
# [[5, 4, 3, 2], [], [1]]
# Calculando las heuristicas
# 31.0 1.0 32.0 [[5, 4, 3, 2], [1], []]
# 28.933333333333334 1.0 29.933333333333334 [[5, 4, 3, 2], [], [1]]
# Estado Actual
# [[5, 4, 3, 2], [], [1]]
# Generando hijos
# Hijo  [0, 1]
# [[5, 4, 3], [2], [1]]
# Calculando las heuristicas
# 31.0 1.0 32.0 [[5, 4, 3, 2], [1], []]
# 28.933333333333334 2.0 30.933333333333334 [[5, 4, 3], [2], [1]]
# Estado Actual
# [[5, 4, 3], [2], [1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 4, 3, 1], [2], []]
# Hijo  [2, 1]
# [[5, 4, 3], [2, 1], []]
# Calculando las heuristicas
# 31.0 1.0 32.0 [[5, 4, 3, 2], [1], []]
# 31.0 3.0 34.0 [[5, 4, 3, 1], [2], []]
# 31.0 3.0 34.0 [[5, 4, 3], [2, 1], []]
# Estado Actual
# [[5, 4, 3, 2], [1], []]
# Generando hijos
# Hijo  [0, 2]
# [[5, 4, 3], [1], [2]]
# Calculando las heuristicas
# 31.0 3.0 34.0 [[5, 4, 3, 1], [2], []]
# 31.0 3.0 34.0 [[5, 4, 3], [2, 1], []]
# 26.866666666666667 2.0 28.866666666666667 [[5, 4, 3], [1], [2]]
# Estado Actual
# [[5, 4, 3], [1], [2]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 4, 3, 1], [], [2]]
# Hijo  [1, 2]
# [[5, 4, 3], [], [2, 1]]
# Calculando las heuristicas
# 31.0 3.0 34.0 [[5, 4, 3, 1], [2], []]
# 31.0 3.0 34.0 [[5, 4, 3], [2, 1], []]
# 26.866666666666667 3.0 29.866666666666667 [[5, 4, 3, 1], [], [2]]
# 24.8 3.0 27.8 [[5, 4, 3], [], [2, 1]]
# Estado Actual
# [[5, 4, 3], [], [2, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[5, 4], [3], [2, 1]]
# Calculando las heuristicas
# 31.0 3.0 34.0 [[5, 4, 3, 1], [2], []]
# 31.0 3.0 34.0 [[5, 4, 3], [2, 1], []]
# 26.866666666666667 3.0 29.866666666666667 [[5, 4, 3, 1], [], [2]]
# 24.8 4.0 28.8 [[5, 4], [3], [2, 1]]
# Estado Actual
# [[5, 4], [3], [2, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 4, 1], [3], [2]]
# Hijo  [2, 1]
# [[5, 4], [3, 1], [2]]
# Calculando las heuristicas
# 31.0 3.0 34.0 [[5, 4, 3, 1], [2], []]
# 31.0 3.0 34.0 [[5, 4, 3], [2, 1], []]
# 26.866666666666667 3.0 29.866666666666667 [[5, 4, 3, 1], [], [2]]
# 26.866666666666667 5.0 31.866666666666667 [[5, 4, 1], [3], [2]]
# 26.866666666666667 5.0 31.866666666666667 [[5, 4], [3, 1], [2]]
# Estado Actual
# [[5, 4, 3, 1], [], [2]]
# Generando hijos
# Calculando las heuristicas
# 31.0 3.0 34.0 [[5, 4, 3, 1], [2], []]
# 31.0 3.0 34.0 [[5, 4, 3], [2, 1], []]
# 26.866666666666667 5.0 31.866666666666667 [[5, 4, 1], [3], [2]]
# 26.866666666666667 5.0 31.866666666666667 [[5, 4], [3, 1], [2]]
# Estado Actual
# [[5, 4, 1], [3], [2]]
# Generando hijos
# Hijo  [2, 1]
# [[5, 4, 1], [3, 2], []]
# Calculando las heuristicas
# 31.0 3.0 34.0 [[5, 4, 3, 1], [2], []]
# 31.0 3.0 34.0 [[5, 4, 3], [2, 1], []]
# 26.866666666666667 5.0 31.866666666666667 [[5, 4], [3, 1], [2]]
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# Estado Actual
# [[5, 4], [3, 1], [2]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 4, 2], [3, 1], []]
# Calculando las heuristicas
# 31.0 3.0 34.0 [[5, 4, 3, 1], [2], []]
# 31.0 3.0 34.0 [[5, 4, 3], [2, 1], []]
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# Estado Actual
# [[5, 4, 3, 1], [2], []]
# Generando hijos
# Calculando las heuristicas
# 31.0 3.0 34.0 [[5, 4, 3], [2, 1], []]
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# Estado Actual
# [[5, 4, 3], [2, 1], []]
# Generando hijos
# Hijo  [0, 2]
# [[5, 4], [2, 1], [3]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 4.0 28.8 [[5, 4], [2, 1], [3]]
# Estado Actual
# [[5, 4], [2, 1], [3]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 4, 1], [2], [3]]
# Hijo  [1, 2]
# [[5, 4], [2], [3, 1]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 5.0 29.8 [[5, 4, 1], [2], [3]]
# 22.733333333333334 5.0 27.733333333333334 [[5, 4], [2], [3, 1]]
# Estado Actual
# [[5, 4], [2], [3, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 4, 2], [], [3, 1]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 5.0 29.8 [[5, 4, 1], [2], [3]]
# 22.733333333333334 6.0 28.733333333333334 [[5, 4, 2], [], [3, 1]]
# Estado Actual
# [[5, 4, 2], [], [3, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 4, 2, 1], [], [3]]
# Hijo  [2, 1]
# [[5, 4, 2], [1], [3]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 5.0 29.8 [[5, 4, 1], [2], [3]]
# 24.8 7.0 31.8 [[5, 4, 2, 1], [], [3]]
# 24.8 7.0 31.8 [[5, 4, 2], [1], [3]]
# Estado Actual
# [[5, 4, 1], [2], [3]]
# Generando hijos
# Hijo  [1, 2]
# [[5, 4, 1], [], [3, 2]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 7.0 31.8 [[5, 4, 2, 1], [], [3]]
# 24.8 7.0 31.8 [[5, 4, 2], [1], [3]]
# 20.666666666666668 6.0 26.666666666666668 [[5, 4, 1], [], [3, 2]]
# Estado Actual
# [[5, 4, 1], [], [3, 2]]
# Generando hijos
# Hijo  [0, 1]
# [[5, 4], [1], [3, 2]]
# Hijo  [0, 2]
# [[5, 4], [], [3, 2, 1]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 7.0 31.8 [[5, 4, 2, 1], [], [3]]
# 24.8 7.0 31.8 [[5, 4, 2], [1], [3]]
# 20.666666666666668 7.0 27.666666666666668 [[5, 4], [1], [3, 2]]
# 18.599999999999998 7.0 25.599999999999998 [[5, 4], [], [3, 2, 1]]
# Estado Actual
# [[5, 4], [], [3, 2, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[5], [4], [3, 2, 1]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 7.0 31.8 [[5, 4, 2, 1], [], [3]]
# 24.8 7.0 31.8 [[5, 4, 2], [1], [3]]
# 20.666666666666668 7.0 27.666666666666668 [[5, 4], [1], [3, 2]]
# 18.599999999999998 8.0 26.599999999999998 [[5], [4], [3, 2, 1]]
# Estado Actual
# [[5], [4], [3, 2, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 1], [4], [3, 2]]
# Hijo  [2, 1]
# [[5], [4, 1], [3, 2]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 7.0 31.8 [[5, 4, 2, 1], [], [3]]
# 24.8 7.0 31.8 [[5, 4, 2], [1], [3]]
# 20.666666666666668 7.0 27.666666666666668 [[5, 4], [1], [3, 2]]
# 20.666666666666668 9.0 29.666666666666668 [[5, 1], [4], [3, 2]]
# 20.666666666666668 9.0 29.666666666666668 [[5], [4, 1], [3, 2]]
# Estado Actual
# [[5, 4], [1], [3, 2]]
# Generando hijos
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 7.0 31.8 [[5, 4, 2, 1], [], [3]]
# 24.8 7.0 31.8 [[5, 4, 2], [1], [3]]
# 20.666666666666668 9.0 29.666666666666668 [[5, 1], [4], [3, 2]]
# 20.666666666666668 9.0 29.666666666666668 [[5], [4, 1], [3, 2]]
# Estado Actual
# [[5, 1], [4], [3, 2]]
# Generando hijos
# Hijo  [2, 1]
# [[5, 1], [4, 2], [3]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 7.0 31.8 [[5, 4, 2, 1], [], [3]]
# 24.8 7.0 31.8 [[5, 4, 2], [1], [3]]
# 20.666666666666668 9.0 29.666666666666668 [[5], [4, 1], [3, 2]]
# 24.8 10.0 34.8 [[5, 1], [4, 2], [3]]
# Estado Actual
# [[5], [4, 1], [3, 2]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 2], [4, 1], [3]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 7.0 31.8 [[5, 4, 2, 1], [], [3]]
# 24.8 7.0 31.8 [[5, 4, 2], [1], [3]]
# 24.8 10.0 34.8 [[5, 1], [4, 2], [3]]
# 24.8 10.0 34.8 [[5, 2], [4, 1], [3]]
# Estado Actual
# [[5, 4, 2, 1], [], [3]]
# Generando hijos
# Hijo  [2, 1]
# [[5, 4, 2, 1], [3], []]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 7.0 31.8 [[5, 4, 2], [1], [3]]
# 24.8 10.0 34.8 [[5, 1], [4, 2], [3]]
# 24.8 10.0 34.8 [[5, 2], [4, 1], [3]]
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# Estado Actual
# [[5, 4, 2], [1], [3]]
# Generando hijos
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 10.0 34.8 [[5, 1], [4, 2], [3]]
# 24.8 10.0 34.8 [[5, 2], [4, 1], [3]]
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# Estado Actual
# [[5, 1], [4, 2], [3]]
# Generando hijos
# Hijo  [0, 1]
# [[5], [4, 2, 1], [3]]
# Hijo  [0, 2]
# [[5], [4, 2], [3, 1]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 10.0 34.8 [[5, 2], [4, 1], [3]]
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 24.8 11.0 35.8 [[5], [4, 2, 1], [3]]
# 22.733333333333334 11.0 33.733333333333334 [[5], [4, 2], [3, 1]]
# Estado Actual
# [[5], [4, 2], [3, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 2], [4], [3, 1]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 10.0 34.8 [[5, 2], [4, 1], [3]]
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 24.8 11.0 35.8 [[5], [4, 2, 1], [3]]
# 22.733333333333334 12.0 34.733333333333334 [[5, 2], [4], [3, 1]]
# Estado Actual
# [[5, 2], [4], [3, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 2, 1], [4], [3]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 24.8 10.0 34.8 [[5, 2], [4, 1], [3]]
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 24.8 11.0 35.8 [[5], [4, 2, 1], [3]]
# 24.8 13.0 37.8 [[5, 2, 1], [4], [3]]
# Estado Actual
# [[5, 2], [4, 1], [3]]
# Generando hijos
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 24.8 11.0 35.8 [[5], [4, 2, 1], [3]]
# 24.8 13.0 37.8 [[5, 2, 1], [4], [3]]
# Estado Actual
# [[5], [4, 2, 1], [3]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 3], [4, 2, 1], []]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 1], [3, 2], []]
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 24.8 13.0 37.8 [[5, 2, 1], [4], [3]]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# Estado Actual
# [[5, 4, 1], [3, 2], []]
# Generando hijos
# Hijo  [0, 1]
# [[5, 4], [3, 2, 1], []]
# Hijo  [0, 2]
# [[5, 4], [3, 2], [1]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 24.8 13.0 37.8 [[5, 2, 1], [4], [3]]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 7.0 38.0 [[5, 4], [3, 2, 1], []]
# 28.933333333333334 7.0 35.93333333333334 [[5, 4], [3, 2], [1]]
# Estado Actual
# [[5, 4], [3, 2], [1]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 4, 2], [3], [1]]
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 24.8 13.0 37.8 [[5, 2, 1], [4], [3]]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 7.0 38.0 [[5, 4], [3, 2, 1], []]
# 28.933333333333334 8.0 36.93333333333334 [[5, 4, 2], [3], [1]]
# Estado Actual
# [[5, 4, 2], [3], [1]]
# Generando hijos
# Calculando las heuristicas
# 31.0 6.0 37.0 [[5, 4, 2], [3, 1], []]
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 24.8 13.0 37.8 [[5, 2, 1], [4], [3]]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 7.0 38.0 [[5, 4], [3, 2, 1], []]
# Estado Actual
# [[5, 4, 2], [3, 1], []]
# Generando hijos
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 24.8 13.0 37.8 [[5, 2, 1], [4], [3]]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 7.0 38.0 [[5, 4], [3, 2, 1], []]
# Estado Actual
# [[5, 2, 1], [4], [3]]
# Generando hijos
# Hijo  [2, 1]
# [[5, 2, 1], [4, 3], []]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 7.0 38.0 [[5, 4], [3, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# Estado Actual
# [[5, 4], [3, 2, 1], []]
# Generando hijos
# Hijo  [0, 2]
# [[5], [3, 2, 1], [4]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 8.0 30.733333333333334 [[5], [3, 2, 1], [4]]
# Estado Actual
# [[5], [3, 2, 1], [4]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 1], [3, 2], [4]]
# Hijo  [1, 2]
# [[5], [3, 2], [4, 1]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 9.0 31.733333333333334 [[5, 1], [3, 2], [4]]
# 20.666666666666668 9.0 29.666666666666668 [[5], [3, 2], [4, 1]]
# Estado Actual
# [[5], [3, 2], [4, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 2], [3], [4, 1]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 9.0 31.733333333333334 [[5, 1], [3, 2], [4]]
# 20.666666666666668 10.0 30.666666666666668 [[5, 2], [3], [4, 1]]
# Estado Actual
# [[5, 2], [3], [4, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 2, 1], [3], [4]]
# Hijo  [2, 1]
# [[5, 2], [3, 1], [4]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 9.0 31.733333333333334 [[5, 1], [3, 2], [4]]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2, 1], [3], [4]]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# Estado Actual
# [[5, 1], [3, 2], [4]]
# Generando hijos
# Hijo  [1, 2]
# [[5, 1], [3], [4, 2]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2, 1], [3], [4]]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 18.599999999999998 10.0 28.599999999999998 [[5, 1], [3], [4, 2]]
# Estado Actual
# [[5, 1], [3], [4, 2]]
# Generando hijos
# Hijo  [0, 1]
# [[5], [3, 1], [4, 2]]
# Hijo  [0, 2]
# [[5], [3], [4, 2, 1]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2, 1], [3], [4]]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 18.599999999999998 11.0 29.599999999999998 [[5], [3, 1], [4, 2]]
# 16.53333333333333 11.0 27.53333333333333 [[5], [3], [4, 2, 1]]
# Estado Actual
# [[5], [3], [4, 2, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 3], [], [4, 2, 1]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2, 1], [3], [4]]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 18.599999999999998 11.0 29.599999999999998 [[5], [3, 1], [4, 2]]
# 16.53333333333333 12.0 28.53333333333333 [[5, 3], [], [4, 2, 1]]
# Estado Actual
# [[5, 3], [], [4, 2, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 3, 1], [], [4, 2]]
# Hijo  [2, 1]
# [[5, 3], [1], [4, 2]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2, 1], [3], [4]]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 18.599999999999998 11.0 29.599999999999998 [[5], [3, 1], [4, 2]]
# 18.599999999999998 13.0 31.599999999999998 [[5, 3, 1], [], [4, 2]]
# 18.599999999999998 13.0 31.599999999999998 [[5, 3], [1], [4, 2]]
# Estado Actual
# [[5], [3, 1], [4, 2]]
# Generando hijos
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2, 1], [3], [4]]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 18.599999999999998 13.0 31.599999999999998 [[5, 3, 1], [], [4, 2]]
# 18.599999999999998 13.0 31.599999999999998 [[5, 3], [1], [4, 2]]
# Estado Actual
# [[5, 3, 1], [], [4, 2]]
# Generando hijos
# Hijo  [2, 1]
# [[5, 3, 1], [2], [4]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2, 1], [3], [4]]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 18.599999999999998 13.0 31.599999999999998 [[5, 3], [1], [4, 2]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# Estado Actual
# [[5, 3], [1], [4, 2]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 3, 2], [1], [4]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2, 1], [3], [4]]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# Estado Actual
# [[5, 2, 1], [3], [4]]
# Generando hijos
# Hijo  [1, 2]
# [[5, 2, 1], [], [4, 3]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 12.0 28.53333333333333 [[5, 2, 1], [], [4, 3]]
# Estado Actual
# [[5, 2, 1], [], [4, 3]]
# Generando hijos
# Hijo  [0, 1]
# [[5, 2], [1], [4, 3]]
# Hijo  [0, 2]
# [[5, 2], [], [4, 3, 1]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 13.0 29.53333333333333 [[5, 2], [1], [4, 3]]
# 14.466666666666667 13.0 27.46666666666667 [[5, 2], [], [4, 3, 1]]
# Estado Actual
# [[5, 2], [], [4, 3, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[5], [2], [4, 3, 1]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 13.0 29.53333333333333 [[5, 2], [1], [4, 3]]
# 14.466666666666667 14.0 28.46666666666667 [[5], [2], [4, 3, 1]]
# Estado Actual
# [[5], [2], [4, 3, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 1], [2], [4, 3]]
# Hijo  [2, 1]
# [[5], [2, 1], [4, 3]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 13.0 29.53333333333333 [[5, 2], [1], [4, 3]]
# 16.53333333333333 15.0 31.53333333333333 [[5, 1], [2], [4, 3]]
# 16.53333333333333 15.0 31.53333333333333 [[5], [2, 1], [4, 3]]
# Estado Actual
# [[5, 2], [1], [4, 3]]
# Generando hijos
# Hijo  [0, 2]
# [[5], [1], [4, 3, 2]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 15.0 31.53333333333333 [[5, 1], [2], [4, 3]]
# 16.53333333333333 15.0 31.53333333333333 [[5], [2, 1], [4, 3]]
# 12.4 14.0 26.4 [[5], [1], [4, 3, 2]]
# Estado Actual
# [[5], [1], [4, 3, 2]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 1], [], [4, 3, 2]]
# Hijo  [1, 2]
# [[5], [], [4, 3, 2, 1]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 15.0 31.53333333333333 [[5, 1], [2], [4, 3]]
# 16.53333333333333 15.0 31.53333333333333 [[5], [2, 1], [4, 3]]
# 12.4 15.0 27.4 [[5, 1], [], [4, 3, 2]]
# 10.333333333333334 15.0 25.333333333333336 [[5], [], [4, 3, 2, 1]]
# Estado Actual
# [[5], [], [4, 3, 2, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[], [5], [4, 3, 2, 1]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 15.0 31.53333333333333 [[5, 1], [2], [4, 3]]
# 16.53333333333333 15.0 31.53333333333333 [[5], [2, 1], [4, 3]]
# 12.4 15.0 27.4 [[5, 1], [], [4, 3, 2]]
# 10.333333333333334 16.0 26.333333333333336 [[], [5], [4, 3, 2, 1]]
# Estado Actual
# [[], [5], [4, 3, 2, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[1], [5], [4, 3, 2]]
# Hijo  [2, 1]
# [[], [5, 1], [4, 3, 2]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 15.0 31.53333333333333 [[5, 1], [2], [4, 3]]
# 16.53333333333333 15.0 31.53333333333333 [[5], [2, 1], [4, 3]]
# 12.4 15.0 27.4 [[5, 1], [], [4, 3, 2]]
# 12.4 17.0 29.4 [[1], [5], [4, 3, 2]]
# 12.4 17.0 29.4 [[], [5, 1], [4, 3, 2]]
# Estado Actual
# [[5, 1], [], [4, 3, 2]]
# Generando hijos
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 15.0 31.53333333333333 [[5, 1], [2], [4, 3]]
# 16.53333333333333 15.0 31.53333333333333 [[5], [2, 1], [4, 3]]
# 12.4 17.0 29.4 [[1], [5], [4, 3, 2]]
# 12.4 17.0 29.4 [[], [5, 1], [4, 3, 2]]
# Estado Actual
# [[1], [5], [4, 3, 2]]
# Generando hijos
# Hijo  [2, 1]
# [[1], [5, 2], [4, 3]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 15.0 31.53333333333333 [[5, 1], [2], [4, 3]]
# 16.53333333333333 15.0 31.53333333333333 [[5], [2, 1], [4, 3]]
# 12.4 17.0 29.4 [[], [5, 1], [4, 3, 2]]
# 16.53333333333333 18.0 34.53333333333333 [[1], [5, 2], [4, 3]]
# Estado Actual
# [[], [5, 1], [4, 3, 2]]
# Generando hijos
# Hijo  [2, 0]
# [[2], [5, 1], [4, 3]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 15.0 31.53333333333333 [[5, 1], [2], [4, 3]]
# 16.53333333333333 15.0 31.53333333333333 [[5], [2, 1], [4, 3]]
# 16.53333333333333 18.0 34.53333333333333 [[1], [5, 2], [4, 3]]
# 16.53333333333333 18.0 34.53333333333333 [[2], [5, 1], [4, 3]]
# Estado Actual
# [[5, 1], [2], [4, 3]]
# Generando hijos
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 15.0 31.53333333333333 [[5], [2, 1], [4, 3]]
# 16.53333333333333 18.0 34.53333333333333 [[1], [5, 2], [4, 3]]
# 16.53333333333333 18.0 34.53333333333333 [[2], [5, 1], [4, 3]]
# Estado Actual
# [[5], [2, 1], [4, 3]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 3], [2, 1], [4]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 11.0 33.733333333333334 [[5, 2], [3, 1], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 18.0 34.53333333333333 [[1], [5, 2], [4, 3]]
# 16.53333333333333 18.0 34.53333333333333 [[2], [5, 1], [4, 3]]
# 22.733333333333334 16.0 38.733333333333334 [[5, 3], [2, 1], [4]]
# Estado Actual
# [[5, 2], [3, 1], [4]]
# Generando hijos
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 18.0 34.53333333333333 [[1], [5, 2], [4, 3]]
# 16.53333333333333 18.0 34.53333333333333 [[2], [5, 1], [4, 3]]
# 22.733333333333334 16.0 38.733333333333334 [[5, 3], [2, 1], [4]]
# Estado Actual
# [[1], [5, 2], [4, 3]]
# Generando hijos
# Hijo  [0, 1]
# [[], [5, 2, 1], [4, 3]]
# Hijo  [0, 2]
# [[], [5, 2], [4, 3, 1]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 18.0 34.53333333333333 [[2], [5, 1], [4, 3]]
# 22.733333333333334 16.0 38.733333333333334 [[5, 3], [2, 1], [4]]
# 16.53333333333333 19.0 35.53333333333333 [[], [5, 2, 1], [4, 3]]
# 14.466666666666667 19.0 33.46666666666667 [[], [5, 2], [4, 3, 1]]
# Estado Actual
# [[], [5, 2], [4, 3, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[2], [5], [4, 3, 1]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 18.0 34.53333333333333 [[2], [5, 1], [4, 3]]
# 22.733333333333334 16.0 38.733333333333334 [[5, 3], [2, 1], [4]]
# 16.53333333333333 19.0 35.53333333333333 [[], [5, 2, 1], [4, 3]]
# 14.466666666666667 20.0 34.46666666666667 [[2], [5], [4, 3, 1]]
# Estado Actual
# [[2], [5], [4, 3, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[2, 1], [5], [4, 3]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 16.53333333333333 18.0 34.53333333333333 [[2], [5, 1], [4, 3]]
# 22.733333333333334 16.0 38.733333333333334 [[5, 3], [2, 1], [4]]
# 16.53333333333333 19.0 35.53333333333333 [[], [5, 2, 1], [4, 3]]
# 16.53333333333333 21.0 37.53333333333333 [[2, 1], [5], [4, 3]]
# Estado Actual
# [[2], [5, 1], [4, 3]]
# Generando hijos
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 22.733333333333334 16.0 38.733333333333334 [[5, 3], [2, 1], [4]]
# 16.53333333333333 19.0 35.53333333333333 [[], [5, 2, 1], [4, 3]]
# 16.53333333333333 21.0 37.53333333333333 [[2, 1], [5], [4, 3]]
# Estado Actual
# [[], [5, 2, 1], [4, 3]]
# Generando hijos
# Hijo  [2, 0]
# [[3], [5, 2, 1], [4]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 1], [2], [4]]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 22.733333333333334 16.0 38.733333333333334 [[5, 3], [2, 1], [4]]
# 16.53333333333333 21.0 37.53333333333333 [[2, 1], [5], [4, 3]]
# 22.733333333333334 20.0 42.733333333333334 [[3], [5, 2, 1], [4]]
# Estado Actual
# [[5, 3, 1], [2], [4]]
# Generando hijos
# Hijo  [0, 2]
# [[5, 3], [2], [4, 1]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 22.733333333333334 16.0 38.733333333333334 [[5, 3], [2, 1], [4]]
# 16.53333333333333 21.0 37.53333333333333 [[2, 1], [5], [4, 3]]
# 22.733333333333334 20.0 42.733333333333334 [[3], [5, 2, 1], [4]]
# 20.666666666666668 15.0 35.66666666666667 [[5, 3], [2], [4, 1]]
# Estado Actual
# [[5, 3], [2], [4, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 3, 2], [], [4, 1]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 22.733333333333334 16.0 38.733333333333334 [[5, 3], [2, 1], [4]]
# 16.53333333333333 21.0 37.53333333333333 [[2, 1], [5], [4, 3]]
# 22.733333333333334 20.0 42.733333333333334 [[3], [5, 2, 1], [4]]
# 20.666666666666668 16.0 36.66666666666667 [[5, 3, 2], [], [4, 1]]
# Estado Actual
# [[5, 3, 2], [], [4, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 3, 2, 1], [], [4]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 14.0 36.733333333333334 [[5, 3, 2], [1], [4]]
# 22.733333333333334 16.0 38.733333333333334 [[5, 3], [2, 1], [4]]
# 16.53333333333333 21.0 37.53333333333333 [[2, 1], [5], [4, 3]]
# 22.733333333333334 20.0 42.733333333333334 [[3], [5, 2, 1], [4]]
# 22.733333333333334 17.0 39.733333333333334 [[5, 3, 2, 1], [], [4]]
# Estado Actual
# [[5, 3, 2], [1], [4]]
# Generando hijos
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 16.0 38.733333333333334 [[5, 3], [2, 1], [4]]
# 16.53333333333333 21.0 37.53333333333333 [[2, 1], [5], [4, 3]]
# 22.733333333333334 20.0 42.733333333333334 [[3], [5, 2, 1], [4]]
# 22.733333333333334 17.0 39.733333333333334 [[5, 3, 2, 1], [], [4]]
# Estado Actual
# [[2, 1], [5], [4, 3]]
# Generando hijos
# Hijo  [2, 1]
# [[2, 1], [5, 3], [4]]
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 16.0 38.733333333333334 [[5, 3], [2, 1], [4]]
# 22.733333333333334 20.0 42.733333333333334 [[3], [5, 2, 1], [4]]
# 22.733333333333334 17.0 39.733333333333334 [[5, 3, 2, 1], [], [4]]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# Estado Actual
# [[5, 3], [2, 1], [4]]
# Generando hijos
# Calculando las heuristicas
# 31.0 8.0 39.0 [[5, 4, 2, 1], [3], []]
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 20.0 42.733333333333334 [[3], [5, 2, 1], [4]]
# 22.733333333333334 17.0 39.733333333333334 [[5, 3, 2, 1], [], [4]]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# Estado Actual
# [[5, 4, 2, 1], [3], []]
# Generando hijos
# Calculando las heuristicas
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 20.0 42.733333333333334 [[3], [5, 2, 1], [4]]
# 22.733333333333334 17.0 39.733333333333334 [[5, 3, 2, 1], [], [4]]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# Estado Actual
# [[5, 3, 2, 1], [], [4]]
# Generando hijos
# Hijo  [2, 1]
# [[5, 3, 2, 1], [4], []]
# Calculando las heuristicas
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 20.0 42.733333333333334 [[3], [5, 2, 1], [4]]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# Estado Actual
# [[3], [5, 2, 1], [4]]
# Generando hijos
# Hijo  [1, 0]
# [[3, 1], [5, 2], [4]]
# Hijo  [1, 2]
# [[3], [5, 2], [4, 1]]
# Calculando las heuristicas
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 21.0 43.733333333333334 [[3, 1], [5, 2], [4]]
# 20.666666666666668 21.0 41.66666666666667 [[3], [5, 2], [4, 1]]
# Estado Actual
# [[3], [5, 2], [4, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[3, 2], [5], [4, 1]]
# Calculando las heuristicas
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 21.0 43.733333333333334 [[3, 1], [5, 2], [4]]
# 20.666666666666668 22.0 42.66666666666667 [[3, 2], [5], [4, 1]]
# Estado Actual
# [[3, 2], [5], [4, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[3, 2, 1], [5], [4]]
# Hijo  [2, 1]
# [[3, 2], [5, 1], [4]]
# Calculando las heuristicas
# 31.0 12.0 43.0 [[5, 3], [4, 2, 1], []]
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 21.0 43.733333333333334 [[3, 1], [5, 2], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# Estado Actual
# [[5, 3], [4, 2, 1], []]
# Generando hijos
# Hijo  [1, 0]
# [[5, 3, 1], [4, 2], []]
# Hijo  [1, 2]
# [[5, 3], [4, 2], [1]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 21.0 43.733333333333334 [[3, 1], [5, 2], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 13.0 44.0 [[5, 3, 1], [4, 2], []]
# 28.933333333333334 13.0 41.93333333333334 [[5, 3], [4, 2], [1]]
# Estado Actual
# [[5, 3], [4, 2], [1]]
# Generando hijos
# Hijo  [1, 0]
# [[5, 3, 2], [4], [1]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 21.0 43.733333333333334 [[3, 1], [5, 2], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 13.0 44.0 [[5, 3, 1], [4, 2], []]
# 28.933333333333334 14.0 42.93333333333334 [[5, 3, 2], [4], [1]]
# Estado Actual
# [[5, 3, 2], [4], [1]]
# Generando hijos
# Hijo  [2, 1]
# [[5, 3, 2], [4, 1], []]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 21.0 43.733333333333334 [[3, 1], [5, 2], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 13.0 44.0 [[5, 3, 1], [4, 2], []]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# Estado Actual
# [[3, 1], [5, 2], [4]]
# Generando hijos
# Hijo  [1, 2]
# [[3, 1], [5], [4, 2]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 13.0 44.0 [[5, 3, 1], [4, 2], []]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 18.599999999999998 22.0 40.599999999999994 [[3, 1], [5], [4, 2]]
# Estado Actual
# [[3, 1], [5], [4, 2]]
# Generando hijos
# Hijo  [0, 1]
# [[3], [5, 1], [4, 2]]
# Hijo  [0, 2]
# [[3], [5], [4, 2, 1]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 13.0 44.0 [[5, 3, 1], [4, 2], []]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 18.599999999999998 23.0 41.599999999999994 [[3], [5, 1], [4, 2]]
# 16.53333333333333 23.0 39.53333333333333 [[3], [5], [4, 2, 1]]
# Estado Actual
# [[3], [5], [4, 2, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[], [5, 3], [4, 2, 1]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 13.0 44.0 [[5, 3, 1], [4, 2], []]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 18.599999999999998 23.0 41.599999999999994 [[3], [5, 1], [4, 2]]
# 16.53333333333333 24.0 40.53333333333333 [[], [5, 3], [4, 2, 1]]
# Estado Actual
# [[], [5, 3], [4, 2, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[1], [5, 3], [4, 2]]
# Hijo  [2, 1]
# [[], [5, 3, 1], [4, 2]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 13.0 44.0 [[5, 3, 1], [4, 2], []]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 18.599999999999998 23.0 41.599999999999994 [[3], [5, 1], [4, 2]]
# 18.599999999999998 25.0 43.599999999999994 [[1], [5, 3], [4, 2]]
# 18.599999999999998 25.0 43.599999999999994 [[], [5, 3, 1], [4, 2]]
# Estado Actual
# [[3], [5, 1], [4, 2]]
# Generando hijos
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 13.0 44.0 [[5, 3, 1], [4, 2], []]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 18.599999999999998 25.0 43.599999999999994 [[1], [5, 3], [4, 2]]
# 18.599999999999998 25.0 43.599999999999994 [[], [5, 3, 1], [4, 2]]
# Estado Actual
# [[1], [5, 3], [4, 2]]
# Generando hijos
# Hijo  [2, 1]
# [[1], [5, 3, 2], [4]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 13.0 44.0 [[5, 3, 1], [4, 2], []]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 18.599999999999998 25.0 43.599999999999994 [[], [5, 3, 1], [4, 2]]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# Estado Actual
# [[], [5, 3, 1], [4, 2]]
# Generando hijos
# Hijo  [2, 0]
# [[2], [5, 3, 1], [4]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 13.0 44.0 [[5, 3, 1], [4, 2], []]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# Estado Actual
# [[5, 3, 1], [4, 2], []]
# Generando hijos
# Hijo  [1, 2]
# [[5, 3, 1], [4], [2]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 26.866666666666667 14.0 40.86666666666667 [[5, 3, 1], [4], [2]]
# Estado Actual
# [[5, 3, 1], [4], [2]]
# Generando hijos
# Hijo  [0, 1]
# [[5, 3], [4, 1], [2]]
# Hijo  [0, 2]
# [[5, 3], [4], [2, 1]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 26.866666666666667 15.0 41.86666666666667 [[5, 3], [4, 1], [2]]
# 24.8 15.0 39.8 [[5, 3], [4], [2, 1]]
# Estado Actual
# [[5, 3], [4], [2, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[5], [4, 3], [2, 1]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 26.866666666666667 15.0 41.86666666666667 [[5, 3], [4, 1], [2]]
# 24.8 16.0 40.8 [[5], [4, 3], [2, 1]]
# Estado Actual
# [[5], [4, 3], [2, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 1], [4, 3], [2]]
# Hijo  [2, 1]
# [[5], [4, 3, 1], [2]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 26.866666666666667 15.0 41.86666666666667 [[5, 3], [4, 1], [2]]
# 26.866666666666667 17.0 43.86666666666667 [[5, 1], [4, 3], [2]]
# 26.866666666666667 17.0 43.86666666666667 [[5], [4, 3, 1], [2]]
# Estado Actual
# [[5, 3], [4, 1], [2]]
# Generando hijos
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 26.866666666666667 17.0 43.86666666666667 [[5, 1], [4, 3], [2]]
# 26.866666666666667 17.0 43.86666666666667 [[5], [4, 3, 1], [2]]
# Estado Actual
# [[5, 1], [4, 3], [2]]
# Generando hijos
# Hijo  [2, 1]
# [[5, 1], [4, 3, 2], []]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 26.866666666666667 17.0 43.86666666666667 [[5], [4, 3, 1], [2]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# Estado Actual
# [[5], [4, 3, 1], [2]]
# Generando hijos
# Hijo  [2, 0]
# [[5, 2], [4, 3, 1], []]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 22.733333333333334 22.0 44.733333333333334 [[2, 1], [5, 3], [4]]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# Estado Actual
# [[2, 1], [5, 3], [4]]
# Generando hijos
# Hijo  [0, 2]
# [[2], [5, 3], [4, 1]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 20.666666666666668 23.0 43.66666666666667 [[2], [5, 3], [4, 1]]
# Estado Actual
# [[2], [5, 3], [4, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[], [5, 3, 2], [4, 1]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 20.666666666666668 24.0 44.66666666666667 [[], [5, 3, 2], [4, 1]]
# Estado Actual
# [[], [5, 3, 2], [4, 1]]
# Generando hijos
# Hijo  [2, 1]
# [[], [5, 3, 2, 1], [4]]
# Calculando las heuristicas
# 31.0 14.0 45.0 [[5, 2, 1], [4, 3], []]
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 22.733333333333334 25.0 47.733333333333334 [[], [5, 3, 2, 1], [4]]
# Estado Actual
# [[5, 2, 1], [4, 3], []]
# Generando hijos
# Hijo  [0, 2]
# [[5, 2], [4, 3], [1]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 22.733333333333334 25.0 47.733333333333334 [[], [5, 3, 2, 1], [4]]
# 28.933333333333334 15.0 43.93333333333334 [[5, 2], [4, 3], [1]]
# Estado Actual
# [[5, 2], [4, 3], [1]]
# Generando hijos
# Hijo  [0, 1]
# [[5], [4, 3, 2], [1]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 22.733333333333334 25.0 47.733333333333334 [[], [5, 3, 2, 1], [4]]
# 28.933333333333334 16.0 44.93333333333334 [[5], [4, 3, 2], [1]]
# Estado Actual
# [[5], [4, 3, 2], [1]]
# Generando hijos
# Hijo  [2, 1]
# [[5], [4, 3, 2, 1], []]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2, 1], [5], [4]]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 22.733333333333334 25.0 47.733333333333334 [[], [5, 3, 2, 1], [4]]
# 31.0 17.0 48.0 [[5], [4, 3, 2, 1], []]
# Estado Actual
# [[3, 2, 1], [5], [4]]
# Generando hijos
# Hijo  [2, 1]
# [[3, 2, 1], [5, 4], []]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 23.0 45.733333333333334 [[3, 2], [5, 1], [4]]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 22.733333333333334 25.0 47.733333333333334 [[], [5, 3, 2, 1], [4]]
# 31.0 17.0 48.0 [[5], [4, 3, 2, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# Estado Actual
# [[3, 2], [5, 1], [4]]
# Generando hijos
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 31.0 15.0 46.0 [[5, 3, 2], [4, 1], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# ...
# 20.666666666666668 27.0 47.66666666666667 [[3, 2, 1], [4], [5]]
# Estado Actual
# [[4, 2, 1], [], [5, 3]]
# Generando hijos
# Hijo  [2, 1]
# [[4, 2, 1], [3], [5]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 26.0 46.66666666666667 [[3], [4, 2, 1], [5]]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 27.0 47.66666666666667 [[3, 2, 1], [4], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# Estado Actual
# [[3], [4, 2, 1], [5]]
# Generando hijos
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 27.0 47.66666666666667 [[3, 2, 1], [4], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# Estado Actual
# [[3, 2, 1], [4], [5]]
# Generando hijos
# Hijo  [1, 2]
# [[3, 2, 1], [], [5, 4]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 28.0 40.4 [[3, 2, 1], [], [5, 4]]
# Estado Actual
# [[3, 2, 1], [], [5, 4]]
# Generando hijos
# Hijo  [0, 1]
# [[3, 2], [1], [5, 4]]
# Hijo  [0, 2]
# [[3, 2], [], [5, 4, 1]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 29.0 41.4 [[3, 2], [1], [5, 4]]
# 10.333333333333334 29.0 39.333333333333336 [[3, 2], [], [5, 4, 1]]
# Estado Actual
# [[3, 2], [], [5, 4, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[3], [2], [5, 4, 1]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 29.0 41.4 [[3, 2], [1], [5, 4]]
# 10.333333333333334 30.0 40.333333333333336 [[3], [2], [5, 4, 1]]
# Estado Actual
# [[3], [2], [5, 4, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[3, 1], [2], [5, 4]]
# Hijo  [2, 1]
# [[3], [2, 1], [5, 4]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 29.0 41.4 [[3, 2], [1], [5, 4]]
# 12.4 31.0 43.4 [[3, 1], [2], [5, 4]]
# 12.4 31.0 43.4 [[3], [2, 1], [5, 4]]
# Estado Actual
# [[3, 2], [1], [5, 4]]
# Generando hijos
# Hijo  [0, 2]
# [[3], [1], [5, 4, 2]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 31.0 43.4 [[3, 1], [2], [5, 4]]
# 12.4 31.0 43.4 [[3], [2, 1], [5, 4]]
# 8.266666666666667 30.0 38.266666666666666 [[3], [1], [5, 4, 2]]
# Estado Actual
# [[3], [1], [5, 4, 2]]
# Generando hijos
# Hijo  [1, 0]
# [[3, 1], [], [5, 4, 2]]
# Hijo  [1, 2]
# [[3], [], [5, 4, 2, 1]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 31.0 43.4 [[3, 1], [2], [5, 4]]
# 12.4 31.0 43.4 [[3], [2, 1], [5, 4]]
# 8.266666666666667 31.0 39.266666666666666 [[3, 1], [], [5, 4, 2]]
# 6.199999999999998 31.0 37.199999999999996 [[3], [], [5, 4, 2, 1]]
# Estado Actual
# [[3], [], [5, 4, 2, 1]]
# Generando hijos
# Hijo  [0, 1]
# [[], [3], [5, 4, 2, 1]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 31.0 43.4 [[3, 1], [2], [5, 4]]
# 12.4 31.0 43.4 [[3], [2, 1], [5, 4]]
# 8.266666666666667 31.0 39.266666666666666 [[3, 1], [], [5, 4, 2]]
# 6.199999999999998 32.0 38.199999999999996 [[], [3], [5, 4, 2, 1]]
# Estado Actual
# [[], [3], [5, 4, 2, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[1], [3], [5, 4, 2]]
# Hijo  [2, 1]
# [[], [3, 1], [5, 4, 2]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 31.0 43.4 [[3, 1], [2], [5, 4]]
# 12.4 31.0 43.4 [[3], [2, 1], [5, 4]]
# 8.266666666666667 31.0 39.266666666666666 [[3, 1], [], [5, 4, 2]]
# 8.266666666666667 33.0 41.266666666666666 [[1], [3], [5, 4, 2]]
# 8.266666666666667 33.0 41.266666666666666 [[], [3, 1], [5, 4, 2]]
# Estado Actual
# [[3, 1], [], [5, 4, 2]]
# Generando hijos
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 31.0 43.4 [[3, 1], [2], [5, 4]]
# 12.4 31.0 43.4 [[3], [2, 1], [5, 4]]
# 8.266666666666667 33.0 41.266666666666666 [[1], [3], [5, 4, 2]]
# 8.266666666666667 33.0 41.266666666666666 [[], [3, 1], [5, 4, 2]]
# Estado Actual
# [[1], [3], [5, 4, 2]]
# Generando hijos
# Hijo  [2, 1]
# [[1], [3, 2], [5, 4]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 31.0 43.4 [[3, 1], [2], [5, 4]]
# 12.4 31.0 43.4 [[3], [2, 1], [5, 4]]
# 8.266666666666667 33.0 41.266666666666666 [[], [3, 1], [5, 4, 2]]
# 12.4 34.0 46.4 [[1], [3, 2], [5, 4]]
# Estado Actual
# [[], [3, 1], [5, 4, 2]]
# Generando hijos
# Hijo  [2, 0]
# [[2], [3, 1], [5, 4]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 31.0 43.4 [[3, 1], [2], [5, 4]]
# 12.4 31.0 43.4 [[3], [2, 1], [5, 4]]
# 12.4 34.0 46.4 [[1], [3, 2], [5, 4]]
# 12.4 34.0 46.4 [[2], [3, 1], [5, 4]]
# Estado Actual
# [[3, 1], [2], [5, 4]]
# Generando hijos
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 31.0 43.4 [[3], [2, 1], [5, 4]]
# 12.4 34.0 46.4 [[1], [3, 2], [5, 4]]
# 12.4 34.0 46.4 [[2], [3, 1], [5, 4]]
# Estado Actual
# [[3], [2, 1], [5, 4]]
# Generando hijos
# Hijo  [0, 2]
# [[], [2, 1], [5, 4, 3]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 34.0 46.4 [[1], [3, 2], [5, 4]]
# 12.4 34.0 46.4 [[2], [3, 1], [5, 4]]
# 6.199999999999998 32.0 38.199999999999996 [[], [2, 1], [5, 4, 3]]
# Estado Actual
# [[], [2, 1], [5, 4, 3]]
# Generando hijos
# Hijo  [1, 0]
# [[1], [2], [5, 4, 3]]
# Hijo  [1, 2]
# [[], [2], [5, 4, 3, 1]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 34.0 46.4 [[1], [3, 2], [5, 4]]
# 12.4 34.0 46.4 [[2], [3, 1], [5, 4]]
# 6.199999999999998 33.0 39.199999999999996 [[1], [2], [5, 4, 3]]
# 4.133333333333333 33.0 37.13333333333333 [[], [2], [5, 4, 3, 1]]
# Estado Actual
# [[], [2], [5, 4, 3, 1]]
# Generando hijos
# Hijo  [1, 0]
# [[2], [], [5, 4, 3, 1]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 34.0 46.4 [[1], [3, 2], [5, 4]]
# 12.4 34.0 46.4 [[2], [3, 1], [5, 4]]
# 6.199999999999998 33.0 39.199999999999996 [[1], [2], [5, 4, 3]]
# 4.133333333333333 34.0 38.13333333333333 [[2], [], [5, 4, 3, 1]]
# Estado Actual
# [[2], [], [5, 4, 3, 1]]
# Generando hijos
# Hijo  [2, 0]
# [[2, 1], [], [5, 4, 3]]
# Hijo  [2, 1]
# [[2], [1], [5, 4, 3]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 34.0 46.4 [[1], [3, 2], [5, 4]]
# 12.4 34.0 46.4 [[2], [3, 1], [5, 4]]
# 6.199999999999998 33.0 39.199999999999996 [[1], [2], [5, 4, 3]]
# 6.199999999999998 35.0 41.199999999999996 [[2, 1], [], [5, 4, 3]]
# 6.199999999999998 35.0 41.199999999999996 [[2], [1], [5, 4, 3]]
# Estado Actual
# [[1], [2], [5, 4, 3]]
# Generando hijos
# Hijo  [1, 2]
# [[1], [], [5, 4, 3, 2]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 34.0 46.4 [[1], [3, 2], [5, 4]]
# 12.4 34.0 46.4 [[2], [3, 1], [5, 4]]
# 6.199999999999998 35.0 41.199999999999996 [[2, 1], [], [5, 4, 3]]
# 6.199999999999998 35.0 41.199999999999996 [[2], [1], [5, 4, 3]]
# 2.0666666666666664 34.0 36.06666666666666 [[1], [], [5, 4, 3, 2]]
# Estado Actual
# [[1], [], [5, 4, 3, 2]]
# Generando hijos
# Hijo  [0, 1]
# [[], [1], [5, 4, 3, 2]]
# Hijo  [0, 2]
# [[], [], [5, 4, 3, 2, 1]]
# Calculando las heuristicas
# 31.0 18.0 49.0 [[5, 3, 2, 1], [4], []]
# 22.733333333333334 26.0 48.733333333333334 [[1], [5, 3, 2], [4]]
# 22.733333333333334 26.0 48.733333333333334 [[2], [5, 3, 1], [4]]
# 31.0 18.0 49.0 [[5, 1], [4, 3, 2], []]
# 31.0 18.0 49.0 [[5, 2], [4, 3, 1], []]
# 31.0 24.0 55.0 [[3, 2, 1], [5, 4], []]
# 31.0 26.0 57.0 [[4], [5, 3, 2, 1], []]
# 20.666666666666668 30.0 50.66666666666667 [[4, 3], [2, 1], [5]]
# 20.666666666666668 32.0 52.66666666666667 [[4, 2, 1], [3], [5]]
# 12.4 34.0 46.4 [[1], [3, 2], [5, 4]]
# 12.4 34.0 46.4 [[2], [3, 1], [5, 4]]
# 6.199999999999998 35.0 41.199999999999996 [[2, 1], [], [5, 4, 3]]
# 6.199999999999998 35.0 41.199999999999996 [[2], [1], [5, 4, 3]]
# 2.0666666666666664 35.0 37.06666666666666 [[], [1], [5, 4, 3, 2]]
# 0.0 35.0 35.0 [[], [], [5, 4, 3, 2, 1]]
# Solucion
# 0 [[5, 4, 3, 2, 1], [], []]
# 1 [[5, 4, 3, 2], [], [1]]
# 2 [[5, 4, 3], [2], [1]]
# 3 [[5, 4, 3], [2, 1], []]
# 4 [[5, 4], [2, 1], [3]]
# 5 [[5, 4, 1], [2], [3]]
# 6 [[5, 4, 1], [], [3, 2]]
# 7 [[5, 4], [], [3, 2, 1]]
# 8 [[5], [4], [3, 2, 1]]
# 9 [[5, 1], [4], [3, 2]]
# 10 [[5, 1], [4, 2], [3]]
# 11 [[5], [4, 2], [3, 1]]
# 12 [[5, 2], [4], [3, 1]]
# 13 [[5, 2, 1], [4], [3]]
# 14 [[5, 2, 1], [4, 3], []]
# 15 [[5, 2], [4, 3], [1]]
# 16 [[5], [4, 3, 2], [1]]
# 17 [[5], [4, 3, 2, 1], []]
# 18 [[], [4, 3, 2, 1], [5]]
# 19 [[1], [4, 3, 2], [5]]
# 20 [[1], [4, 3], [5, 2]]
# 21 [[], [4, 3], [5, 2, 1]]
# 22 [[3], [4], [5, 2, 1]]
# 23 [[3, 1], [4], [5, 2]]
# 24 [[3, 1], [4, 2], [5]]
# 25 [[3], [4, 2], [5, 1]]
# 26 [[3, 2], [4], [5, 1]]
# 27 [[3, 2, 1], [4], [5]]
# 28 [[3, 2, 1], [], [5, 4]]
# 29 [[3, 2], [], [5, 4, 1]]
# 30 [[3], [2], [5, 4, 1]]
# 31 [[3], [2, 1], [5, 4]]
# 32 [[], [2, 1], [5, 4, 3]]
# 33 [[1], [2], [5, 4, 3]]
# 34 [[1], [], [5, 4, 3, 2]]
# 35 [[], [], [5, 4, 3, 2, 1]]
# Iteraciones =
# 156

# %% [markdown]
# TERMINÓ!!!!!
